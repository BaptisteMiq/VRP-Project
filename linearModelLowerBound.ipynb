# %% [markdown]
# # Linear Model to get the lower bound

# %%
from algorithms.google import googleORTools
from tools.graphGeneration import csvToGraph
from tools.graphChecker import calcPathEfficiency
from stats.stats import GetStats, showStats
import numpy as np

# g40 = csvToGraph("dataset/ran-40x40.csv")
# gx1000 = np.multiply(g40, 1000).astype(int).tolist()

# x, dataset = GetStats(2, 40, 2, ["google"], "SIMULATED_ANNEALING", True, gx1000)
# showStats(x, dataset, 40, "worst")


g500 = csvToGraph("dataset/ran-500x500.csv")
x, dataset = GetStats(2, 500, 1, ["tabou"], "", False, g500)
showStats(x, dataset, 500, "worst")

print(dataset)
# Out:
# [{'label': 'Tabou', 'worst': [0.11011079197381585, 0.1332663611768356, 0.14368047996314387, 0.12780080098237834, 0.14593836814335973, 0.11279337688867144, 0.10472858128007928, 0.13462056253488505, 0.14101855497973906, 0.13733740190763105, 0.10984061684646204, 0.11870340412220856, 0.1357280149207266, 0.13587047382797998, 0.11478297849648257, 0.10869864640240723, 0.15453285176408468, 0.1115390033891579, 0.15870097860901522, 0.15625110380744606, 0.1247914075583094, 0.1313149414005163, 0.12930972291112378, 0.1384717046042611, 0.1273764689221635, 0.1549143793684557, 0.16340762560923364, 0.15480755375589328, 0.14054028745366798, 0.13523484454933654, 0.16475596539207985, 0.14243277245724573, 0.13644167311699457, 0.12280246650578952, 0.13939978769969094, 0.1304149488334555, 0.1520436433018478, 0.14805909754049443, 0.1262916763535349, 0.1693790250348456, 0.14494778866738314, 0.13256776244753987, 0.1680022843213594, 0.14224541230908783, 0.1241440495219403, 0.12995564277084928, 0.13647999210955
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-05e7fe9870bb> in <module>
#      13
#      14 g500 = csvToGraph("dataset/ran-500x500.csv")
# ---> 15 x, dataset = GetStats(2, 500, 1, ["tabou"], "", False, g500)
#      16 showStats(x, dataset, 500, "worst")
#      17
#
# ~/Bureau/VRP-Project/stats/stats.py in GetStats(minIterations, maxIterations, padding, algos, _gmeta, doPrint, maxGraph)
#     121         startTime = time.time()
#     122
# --> 123         result = tabu(g, 3, 5)
#     124
#     125         #worst, worstIndex, totLen = calcPathEfficiency(initGraph, result[0], False)
#
# ~/Bureau/VRP-Project/algorithms/tabu.py in tabu(graph, nbVehicules, nbIter, startPoint, concat)
#      41                 for j in range(totPoints):
#      42                     # Check if the path is not used (including other vehicules) + Check if path exists in tabu
# ...
